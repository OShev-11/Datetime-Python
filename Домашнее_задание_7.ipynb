# %% [markdown]
# <a href="https://colab.research.google.com/github/OShev-11/Datetime-Python/blob/main/%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D0%B5%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime

# %%
The_Mos_Time = "Wednesday, October 2, 2002"
The_Guard = "Friday, 11.10.13"
D_News = "Thursday, 18 August 1977"

The_Mos_Time_dt = date_time = datetime.strptime(The_Mos_Time, '%A, %B %d, %Y')
The_Guard_dt = date_time = datetime.strptime(The_Guard, '%A, %d.%m.%y')
D_News_dt = date_time = datetime.strptime(D_News, '%A, %d %B %Y')

print(The_Mos_Time_dt, The_Guard_dt, D_News_dt)
# Out:
# 2002-10-02 00:00:00 2013-10-11 00:00:00 1977-08-18 00:00:00

# %%
from datetime import datetime, timedelta

# %%
def date_range():
    dates = []
    start_date = '2026-01-01'
    end_date = '2026-01-07'
    current_dt = datetime.strptime(start_date, '%Y-%m-%d')
    end_date_dt = datetime.strptime(end_date, '%Y-%m-%d')

    while current_dt <= end_date_dt:
        dates.append(current_dt.strftime('%Y-%m-%d'))
        current_dt += timedelta(days=1)

    return dates

print(date_range())
# Out:
# ['2026-01-01', '2026-01-02', '2026-01-03', '2026-01-04', '2026-01-05', '2026-01-06', '2026-01-07']
